# %% [markdown]
# # Global Video Game Sales

# %% [markdown]
# Project Description

# %% [markdown]
# # Data Wrangling

# %%
# importing modules

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# importing files 
df1 = pd.read_csv('game_info.csv')
df2 = pd.read_csv('Video_Game_Sales_as_of_Jan_2017.csv')

# %% [markdown]
# Variable Descriptions for df1:
#
# - 0id: An unique ID identifying this Game in RAWG Database
# - slug: An unique slug identifying this Game in RAWG Database
# - name: Name of the game
# - metacritic: Rating of the game on Metacritic
# - released: The date the game was released
# - tba: To be announced state
# - updated: The date the game was last updated
# - website: Game Website
# - rating: Rating rated by RAWG user
# - rating_top: Maximum rating
# - playtime: Hours needed to complete the game
# - achievements_count: Number of achievements in game
# - ratings_count: Number of RAWG users who rated the game
# - suggestions_count: Number of RAWG users who suggested the game
# - game_series_count: Number of games in the series
# - reviews_count: Number of RAWG users who reviewed the game
# - platforms: Platforms game was released on. Separated by ||
# - developers: Game developers. Separated by ||
# - genres: Game genres. Separated by ||
# - publishers: Game publishers. Separated by ||
# - esrb_rating: ESRB ratings

# %%
df1.head(10)
# Out:
#        id                         slug                         name  \
# 0       1               dgeneration-hd              D/Generation HD
# 1      10                      g-prime        G Prime Into The Rain
# 2     100                 land-sliders                 Land Sliders
# 3    1000                   pixel-gear                   Pixel Gear
# 4   10000               gods-and-idols               Gods and Idols
# 5  100000                 plague-venue                 Plague venue
# 6  100001         the-moon-sliver-itch       The Moon Sliver (itch)
# 7  100002                   red-entity                   Red Entity
# 8  100004                hippiesvscops                HippiesVsCops
# 9  100005  they-came-through-the-floor  They Came Through the Floor
#
#    metacritic    released    tba              updated  \
# 0         NaN  2015-10-23  False  2019-09-17T11:58:57
# 1         NaN  2016-01-06  False  2019-11-06T23:04:19
# ...

# %% [markdown]
# Variable Descriptions for df2:
#
# - Name - The game's name
# - Platform - Platform of the games release
# - YearofRelease - Year of the game's release
# - Genre - Genre of the game
# - Publisher - Publisher of the game
# - NA_Sales - Sales in North America (in millions)
# - EU_Sales - Sales in Europe (in millions)
# - JP_Sales - Sales in Japan (in millions)
# - Other_Sales - Sales in the rest of the world (in millions)
# - Global_Sales - Total worldwide sales (in millions)
# - Critic_score - Aggregate score compiled by Metacritic staff
# - Critic_count - The number of critics used in coming up with the critic score
# - User_score - Score by Metacritic's subscribers
# - User_count - Number of users who gave the user score
# - Rating - The ESRB ratings

# %%
df2.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue        G           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.54          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.80      3.79         3.29         35.57          82.0
# 3     15.61     10.95      3.28         2.95         32.78          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Rating
# ...

# %%
print(df1.shape, df2.shape)
# Out:
# (474417, 27) (17416, 15)

# %%
# merging the two dataframes 
df_og = df2.merge(df1, how='inner', left_on='Name', right_on='name')

# %%
df_og.shape
# Out:
# (9473, 42)

# %%
df_og.head()
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2  Super Mario Bros.        G           1999.0  Platform  Nintendo      3.40
# 3     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
# 4  Wii Sports Resort      Wii           2009.0    Sports  Nintendo     15.61
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  ...  developers  \
# 0     28.96      3.77         8.45         82.54  ...         NaN
# 1      3.58      6.81         0.77         40.24  ...    Nintendo
# 2      1.30      0.15         0.22          5.07  ...    Nintendo
# 3     12.80      3.79         3.29         35.57  ...         NaN
# 4     10.95      3.28         2.95         32.78  ...    Nintendo
#
#                           genres  publishers  esrb_rating added_status_yet  \
# ...

# %%
df_og.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Rating', 'id', 'slug',
#        'name', 'metacritic', 'released', 'tba', 'updated', 'website', 'rating',
#        'rating_top', 'playtime', 'achievements_count', 'ratings_count',
#        'suggestions_count', 'game_series_count', 'reviews_count', 'platforms',
#        'developers', 'genres', 'publishers', 'esrb_rating', 'added_status_yet',
#        'added_status_owned', 'added_status_beaten', 'added_status_toplay',
#        'added_status_dropped', 'added_status_playing'],
#       dtype='object')

# %%
df_og.isna().sum()
# Out:
# Name                       0
# Platform                   0
# Year_of_Release            3
# Genre                      0
# Publisher                  0
# NA_Sales                   0
# EU_Sales                   0
# JP_Sales                   0
# Other_Sales                0
# Global_Sales               0
# Critic_Score            3526
# Critic_Count            3526
# User_Score              3924
# User_Count              3924
# Rating                  2414
# id                         0
# slug                       0
# name                       0
# metacritic              7195
# released                 360
# tba                        0
# updated                    0
# website                 5124
# rating                     0
# rating_top                 0
# playtime                   0
# achievements_count         0
# ratings_count              0
# suggestions_count          0
# game_series_count          0
# reviews_count              0
# platforms                  8
# ...

# %%
df_og['Critic_Count'].head()
# Out:
# 0    51.0
# 1     NaN
# 2     NaN
# 3    73.0
# 4    73.0
# Name: Critic_Count, dtype: float64

# %%
# drop columns that are not useful, have too many null values or duplicates

df = df_og.drop(columns=['slug', 'tba', 'website', 'esrb_rating', 'added_status_yet',
       'added_status_owned', 'added_status_beaten', 'added_status_toplay',
       'added_status_dropped', 'added_status_playing', 'Critic_Score',
       'Critic_Count', 'User_Score', 'User_Count', 'metacritic', 'genres', 
        'publishers', 'Rating', 'released', 'updated', 'developers', 'name', 'achievements_count', 
        'suggestions_count', 'rating_top', 'id', 'reviews_count', 'Platform'])

# %%
df.isna().sum()
# Out:
# Name                 0
# Year_of_Release      3
# Genre                0
# Publisher            0
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# rating               0
# playtime             0
# ratings_count        0
# game_series_count    0
# platforms            8
# dtype: int64

# %%
df.head(10)
# Out:
#                         Name  Year_of_Release     Genre Publisher  NA_Sales  \
# 0                 Wii Sports           2006.0    Sports  Nintendo     41.36
# 1          Super Mario Bros.           1985.0  Platform  Nintendo     29.08
# 2          Super Mario Bros.           1999.0  Platform  Nintendo      3.40
# 3             Mario Kart Wii           2008.0    Racing  Nintendo     15.68
# 4          Wii Sports Resort           2009.0    Sports  Nintendo     15.61
# 5      New Super Mario Bros.           2006.0  Platform  Nintendo     11.28
# 6                   Wii Play           2006.0      Misc  Nintendo     13.96
# 7  New Super Mario Bros. Wii           2009.0  Platform  Nintendo     14.48
# 8                  Duck Hunt           1984.0   Shooter  Nintendo     26.93
# 9              Mario Kart DS           2005.0    Racing  Nintendo      9.71
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  rating  playtime  \
# ...

# %%
# Data Defintion 

df.dtypes
# Out:
# Name                  object
# Year_of_Release      float64
# Genre                 object
# Publisher             object
# NA_Sales             float64
# EU_Sales             float64
# JP_Sales             float64
# Other_Sales          float64
# Global_Sales         float64
# rating               float64
# playtime               int64
# ratings_count          int64
# game_series_count      int64
# platforms             object
# dtype: object

# %%
# Column Descriptions 

# Name                          
# Year_of_Release      
# Genre                 
# Publisher             
# NA_Sales             North America sales
# EU_Sales             Europe sales
# JP_Sales             Japan sales
# Other_Sales          Sales in other regions 
# Global_Sales         Total sales 
# rating               average rating
# playtime             length of game
# ratings_count        number of ratings
# game_series_count    how many games in the series 
# platforms            platforms game is offered on

# %%
# filling null values 
df.isna().sum()
# Out:
# Name                 0
# Year_of_Release      3
# Genre                0
# Publisher            0
# NA_Sales             0
# EU_Sales             0
# JP_Sales             0
# Other_Sales          0
# Global_Sales         0
# rating               0
# playtime             0
# ratings_count        0
# game_series_count    0
# platforms            8
# dtype: int64

# %%
df[df['Year_of_Release'].isna()]
# Out:
#                               Name  Year_of_Release       Genre  \
# 8123  Mobile Ops: The One Year War              NaN  Simulation
# 8538                  Free Running              NaN      Sports
# 9199  Ferrari: The Race Experience              NaN      Racing
#
#                      Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 8123        Namco Bandai Games       0.0      0.00      0.06          0.0
# 8538        Reef Entertainment       0.0      0.00      0.00          0.0
# 9199  System 3 Arcade Software       0.0      0.01      0.00          0.0
#
#       Global_Sales  rating  playtime  ratings_count  game_series_count  \
# 8123          0.06     0.0         0              0                  0
# 8538          0.01     0.0         2              0                  0
# 9199          0.02     0.0         0              0                  0
#
#               platforms
# 8123           Xbox 360
# 8538  PC||PlayStation 2
# 9199      PlayStation 3

# %%
df[df['platforms'].isna()]
# Out:
#                                                  Name  Year_of_Release  \
# 5049                                 FlatOut: Head On           2008.0
# 5583         Naruto: Ninja Council 2 European Version           2005.0
# 6117                             Tales of the Tempest           2006.0
# 7390                                           NASCAR           2006.0
# 8094                         The Fast and the Furious           2006.0
# 8095                         The Fast and the Furious           2007.0
# 8248                           Ferrari F355 Challenge           2002.0
# 8447  Naruto Shippuden: Dairansen! Kage Bunshin Emaki           2008.0
#
#              Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 5049        Racing           Empire Interactive      0.13      0.10      0.00
# 5583      Fighting             Tomy Corporation      0.00      0.00      0.23
# 6117  Role-Playing           Namco Bandai Games      0.00      0.00      0.18
# ...

# %%
# rows that contain null values have insignificant data, will drop 
df.dropna(axis=0, inplace=True)
df.shape
# Out:
# (9462, 14)

# %%
df.reset_index(inplace=True)

# %%
df.to_csv('clean_df.csv', index=False)
